# %% [markdown]
# # Introduction to Statistics

# %% [markdown]
# “Data Scientist is a person who is better at statistics than any programmer and better at programming than any statistician.” - Josh Wills said,
# ![image.png](attachment:image.png)

# %% [markdown]
# ## I. Introduction to statistic

# %% [markdown]
# ### 1. What is statistic?
# -  Statistics is a Mathematical Science pertaining to data collection, analysis, interpretation and presentation.

# %% [markdown]
# ### 2. Why statistic is important in Data Science?
# - Math and Stats are the building blocks of Machine Learning algorithms. It is important to know the techniques behind various Machine Learning algorithms in order to know how and when to use them.
# - Statistics can be used to derive meaningful insights from data by performing mathematical computations on it.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## II. Terminologies in Statistics - Statistics for Data Science
# - The population is the set of sources from which data has to be collected.
# - A Sample is a subset of the Population
# - A Variable is any characteristics, number, or quantity that can be measured or counted. A variable may also be called a data item.

# %% [markdown]
# Types of analysis:
# - Quantitative Analysis: Quantitative Analysis or Statistical Analysis is the science of collecting and interpreting data with numbers and graphs to identify patterns and trends.
# - Qualitative Analysis: Qualitative or Non-Statistical Analysis gives generic information and uses text, sound and other forms of media to do so.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Categorical data:
# - Nominal values represent discrete units and are used to label variables, that have no quantitative value => distinguish between difference objects, variable identifier and have no order. Examples: name, gender, language,...
# - Ordinal values represent discrete and ordered units => the same with Nominal but Ordinal values have order and the difference between the values is not really known => order objects. Examples: ranking 10 best songs, happiness, customer satisfaction (rank 5 start,..)

# %% [markdown]
# Numerical data:
# - Discrete data: data can only take on certain values => can't be measured but it can be counted => represents information that can be categorized into a classification.
# - Continuous data:
#     - Interval values represent ordered units that have the same difference => a variable that contains numeric values that are ordered and where we know the exact differences between the values. Examples: temperature (...,-2,-1,0,1,2,.. and 0 degree C is not equal 0 degree K or degree F).
#     - Ratio values are also ordered units that have the same difference => Ratio values are the same as interval values but the Zero is exactlly zero.Examples: length(0 cm = 0 m = 0 km, ...), money (0 vnđ = 0 dolar). We can tranform information with a conversion factor.

# %% [markdown]
# #### Why Data Types are important?
# Datatypes are an important concept because statistical methods can only be used with certain data types => analyze continuous data differently than categorical data otherwise it would result in a wrong analysis => choose the correct methods of analysis.
#
# References:
# - https://towardsdatascience.com/data-types-in-statistics-347e152e8bee
# - https://www.mymarketresearchmethods.com/data-types-in-statistics/

# %% [markdown]
# ## III. Categories in Statistics

# %% [markdown]
# ### 1. Categories in statistics
# There are two main categories in Statistics:
# - Descriptive Statistics
# - Inferential Statistics

# %% [markdown]
# ### a. Descriptive statistics and understanding
# - Descriptive Statistics uses the data to provide descriptions of the population, either through numerical calculations or graphs or tables.
# ![image.png](attachment:image.png)

# %% [markdown]
# - Descriptive Statistics used to helps organize data and focuses on the characteristics of data providing parameters => giving short summaries about the sample and measures of the data
# - Descriptive statistics are broken down into measures of central tendency and measures of variability (spread).
#     - Measures of central tendency include the mean, median, and mode.
#     - Measures of variability include the standard deviation, variance, the minimum and maximum variables, and the kurtosis and skewness.
# ![image.png](attachment:image.png)

# %% [markdown]
# Then, descriptive statistics provide a concise summary of data. You can summarize data numerically or graphically.

# %% [markdown]
# ### Measures of central tendency
# - A measure of central tendency is a single value that attempts to describe a set of data by identifying the central position within that set of data => short summary statistics.
# - These measures indicate where most values in a distribution fall and are also referred to as the central location of a distribution => help to fill missing values

# %% [markdown]
# #### 1. Mode
# - The value most recurrent in the sample set.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. Median
# - Measure of the central value of the sample set, the values is ordered
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. Mean
# - Measure of average of all the values in a sample
# ![image.png](attachment:image.png)

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### python code of central tendency

# %%
import random
# Examples data
# Generate 10 random numbers between 10 and 100
randomlist = [random.randrange(1, 50, 1) for i in range(41)] 

print(randomlist)
# Out:
# [17, 16, 10, 5, 33, 21, 13, 30, 35, 27, 22, 16, 48, 16, 2, 28, 3, 14, 1, 10, 32, 45, 32, 3, 38, 20, 14, 18, 7, 44, 8, 2, 41, 46, 7, 10, 41, 28, 12, 37, 25]

# %%
# Import the libraries for plot data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = pd.Series(randomlist,name='values')

# %%
x = pd.DataFrame(data=randomlist)
x = x.rename(columns={0:"values"})

# %%
x.describe()
# Out:
#           values
# count  41.000000
# mean   21.390244
# std    14.058588
# min     1.000000
# 25%    10.000000
# 50%    18.000000
# 75%    32.000000
# max    48.000000

# %%
plt.figure(figsize=(12,10))
x["values"].value_counts()[:len(x["values"].value_counts())].plot(kind='barh')
plt.xlabel("The number of occurences")
plt.ylabel("Values")
# Out:
# Text(0, 0.5, 'Values')

# %%
# count the number of occurrences of a specific values
# randomlist.count(21)

# %%
# print("number of elements in list: ",len(randomlist))

# %%
#mode
print("Mode:",int(scipy.stats.mode(randomlist)[0]))
print("The number of occurrences:",int(scipy.stats.mode(randomlist)[1]))
# Out:
# Mode: 10
# The number of occurrences: 3

# %%
# *** Your code ***

# %%
#median
print("basic median:", statistics.median(randomlist)) # median of values
print("median high:",statistics.median_high(randomlist)) #have no exactlly median, take high values in two median
print("low median:",statistics.median_low(randomlist)) #have no exactlly median, take high values in two median
# Out:
# basic median: 18
# median high: 18
# low median: 18

# %%
# *** Your code ***

# %%
#mean
print("Mean in stats function: ", statistics.mean(randomlist))
print("Mean with numpy array: ",np.mean(randomlist))
# Out:
# Mean in stats function:  21.390243902439025
# Mean with numpy array:  21.390243902439025

# %%
# *** Your code ***

# %% [markdown]
# Reference:
# - https://statisticsbyjim.com/basics/measures-central-tendency-mean-median-mode/
# - https://statistics.laerd.com/statistical-guides/measures-central-tendency-mean-mode-median.php
# - https://realpython.com/python-statistics/

# %% [markdown]
# #### Exercise:
# Build the python code to estimate the Central tendency from the formula

# %% [markdown]
# ### Measures of the Spread
# We also have measures of the spread: Range, Inter Quartile Range (IQR), Variance, Standard Deviation.

# %% [markdown]
# #### Range
# The range is the difference between the smallest value and the largest value in a dataset.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Inter Quartile Range (IQR)
# Quartiles divide an ordered dataset into four equal parts, and refer to the values of the point between the quarters. A dataset may also be divided into quintiles (five equal parts) or deciles (ten equal parts).
# - The lower quartile (Q1) is the point between the lowest 25% of values and the highest 75% of values. It is also called the 25th percentile.
# - The second quartile (Q2) is the middle of the data set. It is also called the 50th percentile, or the median.
# - The upper quartile (Q3) is the point between the lowest 75% and highest 25% of values. It is also called the 75th percentile.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inter Quartile Range (IQR) is the measure of variability, the difference between the upper (Q3) and lower (Q1) quartiles, and describes the middle 50% of values when ordered from lowest to highest
# - The interquartile range is useful in identifying when a value is an outlier.
#
# Ref: https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
# ![image.png](attachment:image.png)

# %% [markdown]
# #### The Variance and Standard deviation

# %% [markdown]
# - Variance describes how much a random variable differs from its expected value(mean).The Variance is defined as the average of the squared of deviations.($\frac{\sum{(x-\bar{x})^2}}{N}$)
#     - Deviation is the difference between each element from the mean (x - $\bar{x}$)
#     - Population Variance is the average of squared deviations.
#     - Sample Variance is the average of squared differences from the mean
# - The Standard Deviation is the measure of the dispersion of a set of data from its mean.. Standard Deviation is just the square root of Variance

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Python code

# %%
from scipy.stats import iqr
iqr(randomlist)
# Out:
# 22.0

# %%
# Interquartile Range
# Import numpy library 
import numpy as np 

# First quartile (Q1) 
Q1 = np.percentile(randomlist, 25, interpolation = 'midpoint') 
  
# Third quartile (Q3) 
Q3 = np.percentile(randomlist, 75, interpolation = 'midpoint') 
  
# Interquaritle range (IQR) 
IQR = Q3 - Q1 
  
print(IQR)
# Out:
# 22.0

# %%
# show inter quartile with box plot 
x.boxplot()

# %%
# Import library and dataset
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')
# Cut the window in 2 parts box plot and histogram
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
 
# Add a graph in each part
sns.boxplot(x['values'], ax=ax_box)
sns.distplot(x['values'], ax=ax_hist)
 
# Remove x axis name for the boxplot
ax_box.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
# Caculate variance 
#numpy.var()
print("variance of data : ", np.var(randomlist))  
# print("variance of data (float32) : ", np.var(randomlist, dtype = np.float32)) # print variance with float32 
# statistics
print("variance of data with statistic : ", statistics.variance(randomlist)) #var in Samples
# Out:
# variance of data :  192.8233194527067
# variance of data (float32) :  192.8233
# variance of data with statistic :  197.6439024390244

# %%
# Calculate standard deviation
# numpy.std()
print("standard deviation of data with numpy : ", np.std(randomlist))  
# statistic
print("standard deviation of data with statistic : ", statistics.stdev(randomlist)) #std in Samples
# Out:
# variance of data :  13.88608366144705
# variance of data :  14.05858820931264

# %% [markdown]
# Ref:
# - https://www.abs.gov.au/websitedbs/a3121120.nsf/home/statistical+language+-+measures+of+spread

# %% [markdown]
# #### Misson: Build all function to calculate variance and standard deviation of population and samples

# %%
# ***Your code here***

# %% [markdown]
# ### b. Inferential Analysis and Understanding

# %% [markdown]
# #### What is inferential statistics?
#
# -  Inferential statistics are techniques that allow us to use a samples to make generalizations about the populations from which the samples were drawn. It is important that the sample accurately represents the population. The process of achieving this is called sampling.
# - The methods of inferential statistics are (1) the estimation of parameter(s) and (2) testing of statistical hypotheses.
#     - Estimating parameters: This means taking a statistic from your sample data (for example the sample mean) and using it to say something about a population parameter (i.e. the population mean).
#     - Hypothesis tests: This is where you can use sample data to answer research questions. For example, you might be interested in knowing if a new cancer drug is effective. Or if breakfast helps children perform better in schools.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### What is Inferential analysis?
# - Inferential analysis is a technique that statisticians use hypothesis testing to formally check whether the hypothesis iss accepted or rejected.
# - Hypothesis testing is an Inferential Statistical technique used to determine whether there is enough evidence in a data sample to infer that a certain condition holds true for an entire population.

# %% [markdown]
# Examples: We want to know that 20000 employees of ABC company get to work on time. But we have no time to ask all of ABC company employees. In the survey, we had 3000 employees answered and 80% of the answers are correct? But we need to check 3000 peoples who can represent for all ABC company employees => now we need to use inferential analysis to check this assumption.

# %% [markdown]
# Then, Inferential statistics use a random sample of data taken from a population to describe and make inferences about the population.

# %% [markdown]
# The probability and hypothesis testing give rise to two important concepts, namely:
# - Null Hypothesis: The result is no different from assumption.
# - Alternate Hypothesis: Result disproves the assumption.
#
# If the probability of an event occurring is less than 5%, then it is a biased event, hence it approves the alternate hypothesis.

# %% [markdown]
# Ref:
# - https://pythonfordatascience.org/inferential-statistics/
# - https://www.analyticsvidhya.com/blog/2017/01/comprehensive-practical-guide-inferential-statistics-data-science/

# %% [markdown]
# #### Code examples with T-test
# The independent t-test is also called the two sample t-test, student’s t-test, or unpaired t-test. It’s a parametric test that tests for a significant difference between the mean of two independent (unrelated) groups.
#
# The hypothesis being tested is:
# - Null hypothesis (H0): u1 = u2, which translates to the mean of sample 1 is equal to the mean of sample 2
# - Alternative hypothesis (HA): u1 <> u2, which translates to the mean of sample 1 is not equal to the mean of sample 2
#
# To determine if there is a significant difference between two groups one must set a p-value before hand; if the test produces a p-value < the set p-value then the test is said to be significant and that there is a significant difference between the two means. This means one rejects the null hypothesis in support of the alternative. Most commonly the p-value is set to 0.05.

# %%
# Importing the required libraries
import pandas as pd
# Two different methods of conducting a t-test
import researchpy as rp
from scipy import stats

df = pd.read_csv("https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master//Iris_Data.csv")

# %% [markdown]
# The data set contains the sepal length and width, as well as the petal length and width of various floral species.
#
# We will test to see if there is a significant difference in the sepal width between the species Iris-setosa and Iris-versicolor which are variables “sepal_width” and “species” respectively.

# %%
# !pip install researchpy

# %%
# Showing descriptive statistics from pandas.describe()
df.groupby("species")['sepal_width'].describe()
# Out:
#                  count   mean       std  min    25%  50%    75%  max
# species
# Iris-setosa       50.0  3.418  0.381024  2.3  3.125  3.4  3.675  4.4
# Iris-versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# Iris-virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
# Showing descriptive statistics from researchpy.summary_cont()
rp.summary_cont(df.groupby("species")['sepal_width'])
# Out:
#                   N   Mean        SD        SE  95% Conf.  Interval
# species
# Iris-setosa      50  3.418  0.381024  0.053885   3.311313  3.524687
# Iris-versicolor  50  2.770  0.313798  0.044378   2.682136  2.857864
# Iris-virginica   50  2.974  0.322497  0.045608   2.883701  3.064299

# %%
# take Iris setosa and Iris versicolor to check
setosa = df[(df['species'] == 'Iris-setosa')]
setosa.reset_index(inplace= True)

versicolor = df[(df['species'] == 'Iris-versicolor')]
versicolor.reset_index(inplace= True)

# %% [markdown]
# #### Assumption Check
# Before the t-test can be conducted, the assumptions of the t-test need to be checked to see if the t-test results can be trusted. First we will check for homogeneity of variances

# %%
stats.levene(setosa['sepal_width'], versicolor['sepal_width'])
# Out:
# LeveneResult(statistic=0.6635459332943233, pvalue=0.4172859681296204)

# %% [markdown]
#  If the resulting p-value of Levene's test is less than some significance level (typically 0.05), the null hypothesis of equal variances is rejected and it is concluded that there is a difference between the variances in the population.

# %% [markdown]
# The test is not significant meaning there is homogeneity of variances and we can proceed. If the test were to be significant, a viable alternative would be to conduct a Welch’s t-test.

# %% [markdown]
# #### Normal distribution of residuals
#
# Next to test the assumption of normality.

# %%
diff = setosa['sepal_width'] - versicolor['sepal_width']

# %%
from scipy import stats
import matplotlib.pyplot as plt

stats.probplot(diff, plot= plt)
plt.title('Sepal Width P-P Plot') 
plt.savefig('Sepal Width Residuals.png')

# %% [markdown]
# The dots should fall on the red line. If the dots are not on the red line then it’s an indication that there is deviation from normality. Some deviations from normality is fine, as long as it’s not severe.

# %%
diff.plot(kind= "hist", title= "Sepal Width Residuals")
plt.xlabel("Length (cm)")
# plt.savefig("Residuals Plot of Sepal Width.png")
# Out:
# Text(0.5, 0, 'Length (cm)')

# %%
stats.shapiro(diff)
# Out:
# (0.9859335422515869, 0.8108891248703003)

# %% [markdown]
# The first value is the W test statistic and the second value is the p-value. Since the test statistic does not produce a significant p-value, the data is indicated to be normally distributed.

# %% [markdown]
# The data met all the assumptions for the t-test which indicates the results can be trusted and the t-test is an appropriate test to be used.

# %% [markdown]
# #### Independent t-test

# %%
# Independent t-test using scipy.stats
stats.ttest_ind(setosa['sepal_width'], versicolor['sepal_width'])
# Out:
# Ttest_indResult(statistic=9.282772555558111, pvalue=4.362239016010214e-15)

# %%
# Independent t-test using researchpy
descriptives, results = rp.ttest(setosa['sepal_width'], versicolor['sepal_width'])

descriptives
# Out:
#       Variable      N   Mean        SD        SE  95% Conf.  Interval
# 0  sepal_width   50.0  3.418  0.381024  0.053885   3.309714  3.526286
# 1  sepal_width   50.0  2.770  0.313798  0.044378   2.680820  2.859180
# 2     combined  100.0  3.094  0.476057  0.047606   2.999540  3.188460

# %%
results
# Out:
#                           Independent t-test  results
# 0  Difference (sepal_width - sepal_width) =    0.6480
# 1                      Degrees of freedom =   98.0000
# 2                                       t =    9.2828
# 3                   Two side test p value =    0.0000
# 4                  Difference < 0 p value =    1.0000
# 5                  Difference > 0 p value =    0.0000
# 6                               Cohen's d =    1.8566
# 7                               Hedge's g =    1.8423
# 8                           Glass's delta =    1.7007
# 9                                       r =    0.6840

# %% [markdown]
# The purpose of the current study was to test if there is a significant difference in the sepal width between the floral species Iris-setosa and Iris-versicolor.
#
# Iris-setosa’s average sepal width (M= 3.418, SD= 0.381) is wider and has slightly larger variation than Iris-versicolor (M= 2.770, SD= 0.314).
#
# An independent t-test was used to test for a difference.
#
# There is a statistically significant difference between the sepal width of Iris-setosa and Iris-versicolor (t(98)= 9.282, p< 0.0001, r= 0.6840).

# %% [markdown]
# #### Mission: what is p-values?
