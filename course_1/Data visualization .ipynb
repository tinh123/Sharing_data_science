# %% [markdown]
# # What is data visualization?
# Data visualization is the presentation of data in a pictorial or graphical format.
# - It enables decision makers to see analytics presented visually, so they can grasp difficult concepts or identify new patterns.
# - When a data scientist is writing advanced predictive analytics or machine learning (ML) algorithms, it becomes important to visualize the outputs to monitor results and ensure that models are performing as intended.

# %% [markdown]
# # Why it's important?
#
# - Data visualization provides a quick and effective way to communicate information in a universal manner using visual information.
#
# With so much data, it’s become increasingly difficult to manage and make sense of it all. It would be impossible for any single person to wade through data line-by-line and see distinct patterns and make observations. Data proliferation can be managed as part of the data science process, which includes data visualization.
# - Improved Insight: Data visualization can provide insight that traditional descriptive statistics cannot.
# - Faster Decision Making: Companies who can gather and quickly act on their data will be more competitive in the marketplace because they can make informed decisions sooner than the competition. Data visualization help  understanding of vast quantities of data by applying visual representations to the data.
# - Basic Example: The table above does an excellent job showing precise if this information is needed. However, it’s difficult to instantaneously see trends and the story the data tells.

# %% [markdown]
# ## Examples of data visualization
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### bar graph
# ![image.png](attachment:image.png)

# %% [markdown]
# ### pie chart
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Line chart
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Area charts
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Histogram
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Time series
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Maps
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tree diagram plot
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Visualization with python

# %% [markdown]
# ### Matplotlib - code examples

# %% [markdown]
# #### The Matplotlib Object Hierarchy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5, 6, 3, 8, 7, 9])
plt.ylabel('some numbers')
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
# %matplotlib notebook

N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Plotting with keyword strings
# - There are some instances where you have data in a format that lets you access particular variables with strings.
# - Matplotlib allows you provide such an object with the data keyword argument. If provided, then you may generate plots with the strings corresponding to these variables.

# %%
# %matplotlib inline 
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

#a, b is key strings, c is colors, s is size of points
plt.scatter('a', 'b', c='c', s='d', data=data) 
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# Plotting with categorical variables
# - It is also possible to create a plot using categorical variables. Matplotlib allows you to pass categorical variables directly to many plotting functions.

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(12, 5))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# Working with multiple figures and axes

# %%
# Examples function return values
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# Working with text
#
# The text() command can be used to add text in an arbitrary location, and the xlabel(), ylabel() and title() are used to add text in the indicated locations.

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# Ref: https://towardsdatascience.com/analyzing-medium-story-stats-with-python-24c6491a8ff0

# %% [markdown]
# ### Plotly - code example

# %%
# simples library for of line plotly
# Standard plotly imports
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
# Using plotly + cufflinks in offline mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/military_data.csv')

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ea942bf769f0> in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
Bokeh - code examples

# %%
Bokeh - code examples

# %% [markdown]
# Practice
#
# Plot all examples in matplotlib documents
#
# Plot all examples in bokeh documents
